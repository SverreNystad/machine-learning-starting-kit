# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import sys
import os

# Get the current working directory
current_working_directory = os.getcwd()

# Go up one level from the current working directory
parent_directory = os.path.join(current_working_directory, '..')

# Add the parent directory to sys.path
sys.path.append(parent_directory)

os.getcwd()
# Out:
# 'c:\\Users\\sverr\\OneDrive\\Desktop\\ai\\machine-learning-structure\\eda'

# %%
# %pip install sweetviz
# %pip install --force-reinstall flask jinja2 sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (3.8.3)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (4.66.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (1.11.4)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from sweetviz) (6.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sverr\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (23.0)
# Requirement already satisfied: pillow>=8 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sverr\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sverr\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: colorama in c:\users\sverr\appdata\roaming\python\python311\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\cli\req_command.py", line 247, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\commands\install.py", line 400, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#                             ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 373, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 204, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 147, in _add_to_criteria
#     matches = self._p.find_matches(
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 224, in find_matches
#     return self._factory.find_candidates(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 266, in _get_installed_candidate
#     if not specifier.contains(installed_dist.version, prereleases=True):
#                               ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_internal\metadata\importlib\_dists.py", line 178, in version
#     return parse_version(self._dist.version)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\packaging\version.py", line 49, in parse
#     return Version(version)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\packaging\version.py", line 264, in __init__
#     match = self._regex.search(version)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: expected string or bytes-like object, got 'NoneType'
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting flask
#   Downloading flask-3.0.2-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.3/101.3 kB 6.1 MB/s eta 0:00:00
# Collecting jinja2
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting dtale
#   Using cached dtale-3.11.0-py2.py3-none-any.whl (14.3 MB)
# Collecting Werkzeug>=3.0.0
#   Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Collecting itsdangerous>=2.1.2
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting blinker>=1.6.2
#   Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Collecting dash-colorscales
#   Using cached dash_colorscales-0.0.4-py3-none-any.whl
# Collecting dash-daq
#   Using cached dash_daq-0.5.0-py3-none-any.whl
# Collecting Flask-Compress
#   Using cached Flask_Compress-1.14-py3-none-any.whl (8.4 kB)
# Collecting future>=0.14.0
#   Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Collecting kaleido
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Collecting missingno
#   Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting pandas
#   Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
# Collecting squarify
#   Using cached squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Collecting strsimpy
#   Using cached strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting xlrd
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting certifi
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting flask-ngrok
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting lz4
#   Using cached lz4-4.3.3-cp311-cp311-win_amd64.whl (99 kB)
# Collecting cycler
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting dash-bootstrap-components<=1.3.1
#   Using cached dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
# Collecting dash
#   Using cached dash-2.16.1-py3-none-any.whl (10.2 MB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Collecting statsmodels
#   Using cached statsmodels-0.14.1-cp311-cp311-win_amd64.whl (9.9 MB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.1.post1-cp311-cp311-win_amd64.whl (10.6 MB)
# Collecting numpy
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Collecting openpyxl!=3.2.0b1
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting xarray
#   Using cached xarray-2024.2.0-py3-none-any.whl (1.1 MB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting plotly
#   Using cached plotly-5.20.0-py3-none-any.whl (15.7 MB)
# Collecting flask
#   Using cached Flask-2.2.5-py3-none-any.whl (101 kB)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting contourpy
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
# Collecting scipy!=1.12.0rc1
#   Using cached scipy-1.12.0-cp311-cp311-win_amd64.whl (46.2 MB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting importlib-metadata
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Collecting typing-extensions>=4.1.1
#   Using cached typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting retrying
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting setuptools
#   Downloading setuptools-69.2.0-py3-none-any.whl (821 kB)
#      ------------------------------------- 821.5/821.5 kB 10.4 MB/s eta 0:00:00
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting packaging
#   Using cached packaging-24.0-py3-none-any.whl (53 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting brotli
#   Using cached Brotli-1.1.0-cp311-cp311-win_amd64.whl (357 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.50.0-cp311-cp311-win_amd64.whl (2.2 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# Collecting pillow>=8
#   Using cached pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Collecting patsy>=0.5.4
#   Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Installing collected packages: strsimpy, squarify, pytz, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, brotli, zipp, xlrd, urllib3, tzdata, typing-extensions, threadpoolctl, tenacity, soupsieve, six, setuptools, pyparsing, pillow, packaging, numpy, networkx, nest-asyncio, MarkupSafe, lz4, kiwisolver, joblib, itsdangerous, idna, future, fonttools, et-xmlfile, cycler, colorama, charset-normalizer, certifi, Werkzeug, scipy, retrying, requests, python-dateutil, plotly, patsy, openpyxl, jinja2, importlib-metadata, contourpy, click, beautifulsoup4, scikit-learn, pandas, matplotlib, flask, xarray, statsmodels, seaborn, flask-ngrok, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
#   Attempting uninstall: strsimpy
#     Found existing installation: strsimpy 0.2.1
#     Uninstalling strsimpy-0.2.1:
#       Successfully uninstalled strsimpy-0.2.1
#   Attempting uninstall: squarify
#     Found existing installation: squarify 0.4.3
#     Uninstalling squarify-0.4.3:
#       Successfully uninstalled squarify-0.4.3
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: kaleido
#     Found existing installation: kaleido 0.2.1
#     Uninstalling kaleido-0.2.1:
#       Successfully uninstalled kaleido-0.2.1
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash-colorscales
#     Found existing installation: dash-colorscales 0.0.4
#     Uninstalling dash-colorscales-0.0.4:
#       Successfully uninstalled dash-colorscales-0.0.4
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.1.0
#     Uninstalling Brotli-1.1.0:
#       Successfully uninstalled Brotli-1.1.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.18.1
#     Uninstalling zipp-3.18.1:
#       Successfully uninstalled zipp-3.18.1
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.1
#     Uninstalling tzdata-2024.1:
#       Successfully uninstalled tzdata-2024.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.4.0
#     Uninstalling threadpoolctl-3.4.0:
#       Successfully uninstalled threadpoolctl-3.4.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.3
#     Uninstalling tenacity-8.2.3:
#       Successfully uninstalled tenacity-8.2.3
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.5
#     Uninstalling soupsieve-2.5:
#       Successfully uninstalled soupsieve-2.5
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
# ERROR: Could not install packages due to an OSError: [WinError 5] Ingen tilgang: 'C:\\Users\\sverr\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\~il\\_imaging.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting flask
#   Using cached flask-3.0.2-py3-none-any.whl (101 kB)
# Collecting jinja2
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting sweetviz
#   Using cached sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
# Collecting Werkzeug>=3.0.0
#   Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Collecting itsdangerous>=2.1.2
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting blinker>=1.6.2
#   Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Collecting pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3
#   Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
# Collecting numpy>=1.16.0
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Collecting matplotlib>=3.1.3
#   Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
# Collecting tqdm>=4.43.0
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Collecting scipy>=1.3.2
#   Using cached scipy-1.12.0-cp311-cp311-win_amd64.whl (46.2 MB)
# Collecting importlib-resources>=1.2.0
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.50.0-cp311-cp311-win_amd64.whl (2.2 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# Collecting packaging>=20.0
#   Using cached packaging-24.0-py3-none-any.whl (53 kB)
# Collecting pillow>=8
#   Using cached pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, six, pyparsing, pillow, packaging, numpy, MarkupSafe, kiwisolver, itsdangerous, importlib-resources, fonttools, cycler, colorama, blinker, Werkzeug, tqdm, scipy, python-dateutil, jinja2, contourpy, click, pandas, matplotlib, flask, sweetviz
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.1
#     Uninstalling tzdata-2024.1:
#       Successfully uninstalled tzdata-2024.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\~yparsing-3.1.2.dist-info due to invalid metadata entry 'name'
#   WARNING: The script f2py.exe is installed in 'c:\Users\sverr\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Ingen tilgang: 'C:\\Users\\sverr\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\~umpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Load data

# %%
import pandas as pd


# Load the dataset
from src.data.data_loader import LocalDataLoader, MockDataLoader
x, y = LocalDataLoader().load_raw_data()
training_data = pd.concat([x, y], axis=1)

# %% [markdown]
# ### Sweetviz
# Sweetviz is a Python library that generates beautiful, high-density visualizations to kickstart exploratory data analysis (EDA) with a single line of code. It's particularly useful for comparing datasets (e.g., training vs. testing) and for analyzing target values within your data.

# %%
import sweetviz as sv
from src.config import FIGURE_PATH, TARGET_FEATURES
# Assuming df is your DataFrame
for feature_name in TARGET_FEATURES:
    report = sv.analyze(training_data, target_feat=feature_name)
    report.show_html(f"{FIGURE_PATH}sweetviz_{feature_name}.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import sweetviz as sv
#       2 from src.config import FIGURE_PATH, TARGET_FEATURES
#       3 # Assuming df is your DataFrame
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\__init__.py:15
#      12 __license__ = "MIT"
#      14 # These are the main API functions
# ---> 15 from sweetviz.sv_public import analyze, compare, compare_intra
#      16 from sweetviz.feature_config import FeatureConfig
#      18 # This is the main report class; holds the report data
#      19 # and is used to output the final report
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\sv_public.py:4
#       1 from typing import Union, List, Tuple
#       2 import pandas as pd
# ----> 4 import sweetviz.dataframe_report
#       5 from sweetviz.feature_config import FeatureConfig
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\dataframe_report.py:10
#       8 from sweetviz.sv_types import NumWithPercent, FeatureToProcess, FeatureType
#       9 import sweetviz.from_dython as associations
# ---> 10 import sweetviz.series_analyzer as sa
#      11 import sweetviz.utils as su
#      12 from sweetviz.graph_associations import GraphAssoc
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\series_analyzer.py:4
#       2 from sweetviz.sv_types import NumWithPercent, FeatureType, FeatureToProcess
#       3 from sweetviz.type_detection import determine_feature_type
# ----> 4 import sweetviz.series_analyzer_numeric
#       5 import sweetviz.series_analyzer_cat
#       6 import sweetviz.series_analyzer_text
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\series_analyzer_numeric.py:4
#       2 import pandas as pd
#       3 from sweetviz.graph_numeric import GraphNumeric
# ----> 4 import sweetviz.sv_html as sv_html
#       5 from sweetviz.sv_types import NumWithPercent, FeatureType, FeatureToProcess
#       6 from sweetviz.config import config
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\sv_html.py:4
#       2 import html
#       3 from operator import itemgetter
# ----> 4 from jinja2 import Environment, PackageLoader
#       5 import sweetviz.sv_html_formatters
#       6 from sweetviz.config import config
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\jinja2\__init__.py:12
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\jinja2\environment.py:25
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\jinja2\defaults.py:3
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# File c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\jinja2\filters.py:13
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      15 from ._compat import abc
#      16 from ._compat import imap
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (c:\Users\sverr\AppData\Local\Programs\Python\Python311\Lib\site-packages\markupsafe\__init__.py)
